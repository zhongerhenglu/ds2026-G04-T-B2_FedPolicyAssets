# %% [markdown]
# # 项目名称 — 模块说明
#
# | 项目   | 内容 |
# |--------|------|
# | 课程   | 数据分析与经济决策（ds2026） |
# | 题目   | T##：XXX |
# | 小组   | 第 X 组 |
# | 成员   | 姓名（学号）、姓名（学号）…… |
# | GitHub | https://github.com/xxx/xxx |
# | Pages  | https://xxx.github.io/xxx |
# | 日期   | YYYY-MM-DD |
